# %%
## Preprocesing method

# %% [markdown]
# # Histogram of Oriented Gradients (HOG):

# %%
from skimage.feature import hog
from skimage import data, exposure
import matplotlib.pyplot as plt


# Example usage on a single image
image = data.astronaut()  # Replace with your own image
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),
                    cells_per_block=(1, 1), visualize=True, multichannel=True)

# Visualize the HOG image
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))
plt.imshow(hog_image_rescaled)
plt.axis('off')
plt.show()
# Out:
# /tmp/ipykernel_16262/2803116191.py:8: FutureWarning: `multichannel` is a deprecated argument name for `hog`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16, 16),

# %%
image.shape
# Out:
# (512, 512)

# %%
import numpy as np
from PIL import Image
plt.imshow(image, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

image = Image.fromarray(image.astype(np.uint8))

image.save('image.jpg')

# %% [markdown]
# # 2.Scale-Invariant Feature Transform (SIFT):

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

#reading image
img1 = cv2.imread('image.jpg')  
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

#keypoints
sift = cv2.xfeatures2d.SIFT_create()
keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)

img_1 = cv2.drawKeypoints(gray1,keypoints_1,img1)
plt.imshow(img_1)
# Out:
# [ WARN:0@154840.961] global /io/opencv_contrib/modules/xfeatures2d/misc/python/shadow_sift.hpp (13) SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736

# %% [markdown]
# # 3. Speeded Up Robust Features (SURF):

# %%
# import cv2

# # Example usage on a single image
# image = cv2.imread("image.jpg", cv2.IMREAD_GRAYSCALE)  # Replace with your own image
# surf = cv2.xfeatures2d.SURF_create()

# keypoints, descriptors = surf.detectAndCompute(image, None)

# # Visualize keypoints
# image_with_keypoints = cv2.drawKeypoints(image, keypoints, None)
# img_1 = cv2.drawKeypoints(image,keypoints,image_with_keypoints)
# plt.imshow(img_1)

# %% [markdown]
# # 4. Local Binary Patterns (LBP):

# %%
import cv2
import numpy as np
from skimage import data
import matplotlib.pyplot as plt
from skimage.color import label2rgb
from skimage.transform import rotate
from skimage.feature import local_binary_pattern


# settings for LBP
radius = 3
n_points = 8 * radius

image = cv2.imread('image.jpg')

# Convert the array to grayscale and reshape it to (height, width)
image = np.mean(image, axis=2).astype(np.uint8)

lbp = local_binary_pattern(image, n_points, radius, method = "uniform")
plt.imshow(lbp)
